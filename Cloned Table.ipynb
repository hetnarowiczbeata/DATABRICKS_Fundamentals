-- %%
select * from workspace.default.weather_test

-- %% [markdown]
-- klonowanie tabeli na bazie istniejacej

-- %%
CREATE TABLE workspace.default.weather_test_cloned
DEEP clone workspace.default.weather_test

-- %% [markdown]
-- -- moze byc deep clone albo shallow. w shallow mamy tylko kopie metadanych
