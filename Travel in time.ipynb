-- %%
SELECT * FROM samples.accuweather.forecast_daily_calendar_imperial WHERE wind_speed_min>3.5

-- %%
CREATE TABLE workspace.default.weather_test AS
SELECT *
FROM samples.accuweather.forecast_daily_calendar_imperial

-- %%
select * from workspace.default.weather_test

-- %%
UPDATE workspace.default.weather_test
SET cloud_cover_perc_avg = cloud_cover_perc_avg + 10
WHERE cloud_cover_perc_avg > 50

-- %%
DELETE FROM workspace.default.weather_test
WHERE city_name='osaka-shi'

-- %%
describe history workspace.default.weather_test

-- %%
select * from workspace.default.weather_test version as of 2

-- %%
SELECT * FROM workspace.default.weather_test TIMESTAMP AS OF '2026-09-18T08:41:17'
