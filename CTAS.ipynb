-- %%
select * from workspace.default.weather_test

-- %% [markdown]
-- CTAS znaczy create table as select

-- %%
CREATE TABLE workspace.default.weather_test_filtered
AS
SELECT * FROM workspace.default.weather_test
WHERE city_name='amsterdam'

-- %%
SELECT * FROM workspace.default.weather_test_filtered
