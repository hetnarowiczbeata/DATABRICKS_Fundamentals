-- %%
USE CATALOG workspace;
USE SCHEMA default;
select * from weather_test;

-- %%
CREATE OR REPLACE VIEW weather_test_view AS
SELECT * FROM weather_test WHERE date >= '2024-01-01' AND date <= '2024-12-31';

-- %%
SELECT * FROM weather_test_view

-- %% [markdown]
-- mozna tez tworzyc widoki tymczasowe ktore beda aktywne tak dlugo jak trwa sesja

-- %%
CREATE OR REPLACE TEMP VIEW weather_test_view AS
SELECT * FROM weather_test WHERE date >= '2024-01-01' AND date <= '2024-12-31';

-- %% [markdown]
-- Jest jeszcze cos takiego jak global temp i to znaczy ze taki widok zyje dluzej/tyle ilu klaster

-- %%
CREATE OR REPLACE GLOBAL TEMP VIEW weather_test_view_half AS
SELECT * FROM weather_test WHERE date >= '2024-01-01' AND date <= '2024-06-30';

-- %%
SELECT * FROM global_temp.weather_test_view_half
