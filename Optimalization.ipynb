-- %%
select * from workspace.default.weather_test

-- %%
describe detail workspace.default.weather_test

-- %% [markdown]
-- tu widać, że plik jest w formacie delta co umożliwia zarządzanie danymi np. update, mamy również logi transakcyjne czyli dziennik wszystkich zmian, widać również, że numfiles=1 wiec nie ma czego optymalizowac, poniższe zadania w celach treningowych

-- %%
OPTIMIZE workspace.default.weather_test ZORDER BY (date)

-- %% [markdown]
-- ZORDER określa kolumnę lub kolumny, według których dane są fizycznie lepiej grupowane w plikach, aby Databricks mógł szybciej pomijać niepotrzebne pliki podczas filtrowania
